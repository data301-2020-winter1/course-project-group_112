# %%
import pandas as pd

music = pd.read_csv('Spotify-2000.csv')
music.head(100)
# Out:
#     Index                                              Title  \
# 0       1                                            Sunrise
# 1       2                                        Black Night
# 2       3                                     Clint Eastwood
# 3       4                                      The Pretender
# 4       5                             Waitin' On A Sunny Day
# ..    ...                                                ...
# 95     96                                            21 Guns
# 96     97  Valerie (feat. Amy Winehouse) - Version Revisited
# 97     98                                        Blaosmuziek
# 98     99                                             Binnen
# 99    100                               Motorcycle Emptiness
#
#                     Artist            Top Genre  Year  Beats Per Minute (BPM)  \
# 0              Norah Jones      adult standards  2004                     157
# ...
